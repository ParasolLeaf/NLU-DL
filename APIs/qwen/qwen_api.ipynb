# %%
import os
from openai import OpenAI
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

client = OpenAI(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    # api_key="sk-XXX", # 如何获取API Key：https://help.aliyun.com/zh/model-studio/developer-reference/get-api-key
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)


completion = client.chat.completions.create(
    # 模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    model="qwen-plus",  # qwen-plus 属于 qwen3 模型，如需开启思考模式，请参见：https://help.aliyun.com/zh/model-studio/deep-thinking
    messages=[
        {'role': 'user', 'content': '你是谁？'}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 我是通义千问，阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我可以帮助你回答问题、创作文字，比如写故事、写公文、写邮件、写剧本、逻辑推理、编程等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，欢迎随时告诉我！

# %%
import os
from openai import OpenAI
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

client = OpenAI(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    # api_key="sk-XXX", # 如何获取API Key：https://help.aliyun.com/zh/model-studio/developer-reference/get-api-key
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)


completion = client.chat.completions.create(
    # 模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    model="qwen-plus",  # qwen-plus 属于 qwen3 模型，如需开启思考模式，请参见：https://help.aliyun.com/zh/model-studio/deep-thinking
    messages=[
        {'role': 'user', 'content': '你是谁？'},
        {'role': 'assistant', 'content':'我是通义千问，阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我可以帮助你回答问题、创作文字，比如写故事、写公文、写邮件、写剧本、逻辑推理、编程等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，欢迎随时告诉我！'},
        {'role': 'user', 'content': '复述一遍你之前说的话的第一句。'}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 我是通义千问，阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。

# %%
import os
from openai import OpenAI
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

client = OpenAI(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    # api_key="sk-XXX",
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

completion = client.chat.completions.create(
    # 模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    model="qwen-plus",
    messages=[
        #{"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "你好"},
    ],
    n=3,
    temperature=1.8
    # Qwen3模型通过enable_thinking参数控制思考过程（开源版默认True，商业版默认False）
    # 使用Qwen3开源版模型时，若未启用流式输出，请将下行取消注释，否则会报错
    # extra_body={"enable_thinking": False},
)
print(completion)
print(completion.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-3fd6400f-bcb0-952d-a903-73adfa9d26f5', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好呀！🌟 有什么有趣的事情想和我分享，或者有什么问题需要帮忙的吗？', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)), Choice(finish_reason='stop', index=1, logprobs=None, message=ChatCompletionMessage(content='你好呀！✨ 很高兴见到你！今天过得怎么样呀？希望你度过了愉快天。我刚刚晒完太阳，正在花园里泡了一壶花茶，如果你愿意的话，可以来陪我聊聊天哦~ 🌸💬', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)), Choice(finish_reason='stop', index=2, logprobs=None, message=ChatCompletionMessage(content='你好呀！✨ 很高兴见到你！今天过得怎么样呀？希望你度过了的一天。我随时准备好陪你聊天、帮你解决问题，或者就这样轻松愉快地闲聊一会儿。有什么想跟我分享的吗？ 🌟', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1751209177, model='qwen-plus', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=124, prompt_tokens=13, total_tokens=137, completion_tokens_details=None, prompt_tokens_details=None))
# 你好呀！🌟 有什么有趣的事情想和我分享，或者有什么问题需要帮忙的吗？

# %%
import os
from openai import OpenAI
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

client = OpenAI(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    api_key="sk-XXX",
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)
completion = client.chat.completions.create(
    model="qwen-vl-plus",  # 此处以qwen-vl-plus为例，可按需更换模型名称。模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    messages=[{"role": "user","content": [
            {"type": "image_url",
             "image_url": {"url": "https://dashscope.oss-cn-beijing.aliyuncs.com/images/dog_and_girl.jpeg"}},
            {"type": "text", "text": "这张图片描述了什么内容"},
            ]}]
    )
print(completion.model_dump_json())
# Out:
# {"id":"chatcmpl-df528890-a0de-93e7-bb83-85a0413526c1","choices":[{"finish_reason":"stop","index":0,"logprobs":null,"message":{"content":"这张图片展示了一位女性和一只狗在海滩上互动的温馨场景。女性坐在沙滩上，穿着格子衬衫和黑色裤子，面带微笑，似乎在与狗进行友好交流。狗是一只金毛猎犬，戴着彩色的项圈，正用前爪轻轻触碰女性的手，显示出它们之间亲密的关系。背景是广阔的海洋和天空，夕阳的余晖洒在沙滩上，营造出一种宁静而美好的氛围。整体画面充满了温暖和和谐的感觉，体现了人与宠物之间的美好时光。","refusal":null,"role":"assistant","annotations":null,"audio":null,"function_call":null,"tool_calls":null}}],"created":1751209185,"model":"qwen-vl-plus","object":"chat.completion","service_tier":null,"system_fingerprint":null,"usage":{"completion_tokens":113,"prompt_tokens":1263,"total_tokens":1376,"completion_tokens_details":null,"prompt_tokens_details":{"audio_tokens":null,"cached_tokens":0}}}

# %%
from openai import OpenAI
import os
import base64
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

base64_image = encode_image("./image.jpg")

client = OpenAI(
    # api_key="sk-XXX",
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)
completion = client.chat.completions.create(
    model="qwen-vl-plus",
    messages=[
    	{"role": "system","content": [{"type":"text","text": "You are a helpful assistant."}]},
        {"role": "user",
            "content": [
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}},
                {"type": "image_url","image_url": {"url": "https://dashscope.oss-cn-beijing.aliyuncs.com/images/dog_and_girl.jpeg"}},
                {"type": "text", "text": "介绍这两幅不同的图像。"},
            ],
        }
    ],
)
print(completion.choices[0].message.content)
# Out:
# 这两幅图像展示了完全不同的场景和氛围：
#
# 1. **第一幅图像**：
#    - 这是一张厨房的内部照片。
#    - 厨房墙面贴有浅色瓷砖，上面装饰着水果图案的墙纸，营造出一种温馨的家居氛围。
#    - 桌面上摆放着一些烹饪用具，包括锅、碗和其他厨具，显示出这是一个正在使用的厨房环境。
#    - 左侧可以看到一个电磁炉，上面放着两个锅，表明这里可能正在进行或刚刚完成烹饪活动。
#    - 右侧有一个水壶和饮水机，旁边还有一些杂物，整体给人一种实用且略显杂乱的感觉。
#    - 整体照明较为柔和，可能是自然光与室内灯光结合的效果。
#
# 2. **第二幅图像**：
#    - 这是一张在海滩上拍摄的照片，展示了一位女性和一只狗之间的互动。
#    - 女性坐在沙滩上，穿着格子衬衫和短裤，面带微笑，显得非常开心。
#    - 狗（看起来像金毛猎犬）也坐在沙地上，戴着彩色项圈，正伸出前爪与女性互动，似乎是在握手。
#    - 海浪轻轻拍打着海岸线，背景是广阔的天空和海洋，夕阳的余晖洒在地平线上，整个画面充满了温暖和宁静的氛围。
#    - 场景传达出人与宠物之间亲密无间的友谊以及户外休闲的乐趣。
#
# ### 总结：
# - 第一幅图像呈现了一个功能性的厨房环境，强调实用性与日常生活的气息。
# - 第二幅图像则捕捉到了人与宠物在自然美景中的和谐互动，传递出轻松愉悦的情感体验。两者虽然风格迥异，但都展现了各自独特的美感和生活片段。

# %%
from openai import OpenAI
import os
from pathlib import Path
from dotenv import load_dotenv

dotenv_path = Path(__file__).resolve().parent.parent.parent / '.env'  # 根据实际路径调整
load_dotenv()

client = OpenAI(
    # api_key="sk-XXX",
    api_key=os.getenv("QWEN_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

messages = [{"role": "user", "content": "你是谁"}]

completion = client.chat.completions.create(
    model="qwen-plus-2025-04-28",  # 您可以按需更换为其它深度思考模型
    messages=messages,
    extra_body={"enable_thinking": True},# enable_thinking 参数开启思考过程，QwQ 与 DeepSeek-R1 模型总会进行思考，不支持该参数
    stream=True,
)

reasoning_content = ""  # 完整思考过程
answer_content = ""  # 完整回复
is_answering = False  # 是否进入回复阶段
print("\n" + "=" * 20 + "思考过程" + "=" * 20 + "\n")

for chunk in completion:
    delta = chunk.choices[0].delta
    # 只收集思考内容
    if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
        if not is_answering:
            print(delta.reasoning_content, end="", flush=True)
        reasoning_content += delta.reasoning_content

    # 收到content，开始进行回复
    if hasattr(delta, "content") and delta.content:
        if not is_answering:
            print("\n" + "=" * 20 + "完整回复" + "=" * 20 + "\n")
            is_answering = True
        print(delta.content, end="", flush=True)
        answer_content += delta.content
# Out:
# ====================思考过程====================
#
# 嗯，用户问“你是谁”，我需要先确定他们想知道什么。可能他们第一次接触我，或者想确认我的身份。我应该先介绍自己的名字，通义千问，然后说明我是通义实验室研发的超大规模语言模型。接下来要提到我的功能，比如回答问题、创作文字、编程等，这样用户能了解我能做什么。还要加入一些亲切的话，比如“很高兴为你提供帮助！”让回复更友好。另外，用户可能想知道我和竞品的区别，但问题没直接问，所以暂时简要回答，保持简洁。注意用口语化的中文，避免太正式。检查有没有遗漏的信息，比如多语言支持，或者具体例子，但可能在这里不需要，保持回答简短。最后确认语气是否自然，有没有错误。好的，这样应该可以了。
# ====================完整回复====================
#
# 我是通义千问，阿里巴巴集团旗下的超大规模语言模型。我可以帮助你回答问题、创作文字（比如写故事、写公文、写邮件、写剧本等）、进行逻辑推理、编程，甚至表达观点和玩游戏。如果你有任何问题或需要帮助，随时告诉我！
